# %% [markdown]
# <a href="https://colab.research.google.com/github/akd5488/Visual-Analytics/blob/master/Copy_of_TeamProject1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Title: Total Precipitation per Year

# %% [markdown]
# #### Creators
#
#
# *   Bryce Hoffman
# *   Adam Donofrio
# *   Louis Sentman

# %% [markdown]
# ### Original Project (Lab Assignment 1)

# %% [markdown]
# This graph will compare how the daily high and low temperatures impact the amount of precipitation recieved, either as snow or rain. Only data from March 2017 will be analyized.

# %% [markdown]
# ![lab1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# The graph sketched shows the realtionship between temperature and if there was rain or snow. Colder days brought snow. The most precipitation was on the coldest days.

# %% [markdown]
# ### Team Project 1

# %% [markdown]
# When considering the options on which topic to do for the group project we choose to graph the precipition in State College over the last 20 years. More specifically, we decided to focus on the average precipition and the maximum precipition. To start with the main layout of the visual graph we went with an area type chart embedded with a line graph. Overall, we thought this would be the most appealing to the viewer all while keeping it simple and easy to read. After we choose the type of visual, we added a few retinal variables as you can see the difference below.

# %% [markdown]
# #### The Good

# %% [markdown]
# After making three separate graphs this graph was the "good" graph or the best graph out of the three. When considering the retinal variables such as color, size, position, etc. It is evident this graph has it all compared to the other two graphs. First, we choose an appealing pink color that catches the viewers' attention but also is not obnoxious at the same time. After we choose the solid single-color scheme, a maximum line was added for the highest day of precipitation for each year from the last 20 years. The next line that is a good aid and helpful to the graph which adds important information is the average line of precipitation. This is good because it allows the viewer to compare the overall averages over the last 20 years to get a general comparison.

# %%
import IPython
IPython.display.HTML("<div class='tableauPlaceholder' id='viz1581087239659' style='position: relative'><noscript><a href=''><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Th&#47;Thegood&#47;Sheet1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='Thegood&#47;Sheet1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Th&#47;Thegood&#47;Sheet1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1581087239659');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>")
# Out:
# <div class='tableauPlaceholder' id='viz1581087239659' style='position: relative'><noscript><a href=''><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Th&#47;Thegood&#47;Sheet1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='Thegood&#47;Sheet1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Th&#47;Thegood&#47;Sheet1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='filter' value='publish=yes' /></object></div>  
# ...

# %% [markdown]
# #### The Bad

# %% [markdown]
# When viewing a pie chart, the user expects that each "slice" represents a portion of a whole. However, our graphs are comparing total precipitation per year. The total amount of precipitation is not relevant to the graph. The graph draws the conclusion that the preciptation per year is being compared to the total amount of precipitation recorded. It is very hard to tell what year has the most preciptation or what an average amount of precipitation is. If a person is just looking at the graph and cannot interact with it, there is no way to tell how much precipitation each pie slice represents. The numeric amount of precipitation each year is absent from the graph. The colors selected for the graph are random and have no idication on a higher or lower amount of precipitation.

# %%
import IPython
IPython.display.HTML("<div class='tableauPlaceholder' id='viz1581086525215' style='position: relative'><noscript><a href=''><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Th&#47;Thebad&#47;Sheet1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='Thebad&#47;Sheet1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Th&#47;Thebad&#47;Sheet1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1581086525215');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>")
# Out:
# <div class='tableauPlaceholder' id='viz1581086525215' style='position: relative'><noscript><a href=''><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Th&#47;Thebad&#47;Sheet1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='Thebad&#47;Sheet1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Th&#47;Thebad&#47;Sheet1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='filter' value='publish=yes' /></object></div>     
# ...

# %% [markdown]
# #### The Ugly

# %% [markdown]
# Although this graph can accurately convey the Data from the File, it does not do so very well. For  example, there is no cronoligical patern to the graph. This does not allow the user to see trends over time. Furthermore, It is difficult to distiguish the difference between some years without hovering over the circle for that year. Next, there is no order to the data; meaning the data is not organized by magnitude or the aformentioned time. Finally, there is no frame of reference to what is the average rainfall during the span of time this data covers. As well as, there is no reference point to the max or min rainfall recieved during a year.

# %%
import IPython
IPython.display.HTML("<div class='tableauPlaceholder' id='viz1581086370585' style='position: relative'><noscript><a href=''><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Th&#47;Theugly&#47;Sheet1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='Theugly&#47;Sheet1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Th&#47;Theugly&#47;Sheet1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1581086370585');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>")
# Out:
# <div class='tableauPlaceholder' id='viz1581086370585' style='position: relative'><noscript><a href=''><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Th&#47;Theugly&#47;Sheet1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='Theugly&#47;Sheet1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Th&#47;Theugly&#47;Sheet1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='filter' value='publish=yes' /></object></div>  
# ...
